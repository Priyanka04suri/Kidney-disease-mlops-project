# %%
# config box
d = {"key":"val", "key1":"val1"}

# %%
d['key1']
# Out:
# 'val1'

# %%
d.key1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 d.key1
#
# AttributeError: 'dict' object has no attribute 'key1'

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key":"val", "key1":"val1"})

# %%
d2.key1
# Out:
# 'val1'

# %%
type(d2)
# Out:
# box.config_box.ConfigBox

# %%
type(d)
# Out:
# dict

# %%
# ensure annotations 

def get_prodict(x:int, y:int) -> int:
    return x*y

# %%
get_prodict(x=2, y=3)
# Out:
# 6

# %%
get_prodict(x=2, y="3")
# Out:
# '33'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_prodict(x:int, y:int) -> int:
    return x*y

# %%
get_prodict(x=2, y=3)
# Out:
# 6

# %%
get_prodict(x=2, y="3")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 get_prodict(x=2, y="3")
#
# File ~/miniconda3/envs/kidney/lib/python3.10/site-packages/ensure/main.py:845, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     840     if not isinstance(value, templ):
#     841         msg = (
#     842             "Argument {arg} of type {valt} to {f} "
#     843             "does not match annotation type {t}"
#     844         )
# --> 845         raise EnsureError(msg.format(
#     846             arg=arg, f=self.f, t=templ, valt=type(value)
#     847         ))
#     849 return_val = self.f(*args, **kwargs)
#     850 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get_prodict at 0x10645c4c0> does not match annotation type <class 'int'>

# %% [markdown]
# Donwload data from gdrive (google drive)

# %%
import gdown

# %%
url="https://drive.google.com/file/d/19HjUG8tcTxp5WkdSzGXe4E1FVzjqRvdJ/view?usp=drive_link"

# %%
url.split("/")
# Out:
# ['https:',
#  '',
#  'drive.google.com',
#  'file',
#  'd',
#  '19HjUG8tcTxp5WkdSzGXe4E1FVzjqRvdJ',
#  'view?usp=drive_link']

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '19HjUG8tcTxp5WkdSzGXe4E1FVzjqRvdJ'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id=' # when we open a file on google drive then we download it using top-right download button so this url is for that download button
gdown.download(prefix+file_id, "kidney-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=19HjUG8tcTxp5WkdSzGXe4E1FVzjqRvdJ
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=19HjUG8tcTxp5WkdSzGXe4E1FVzjqRvdJ&confirm=t&uuid=d7034298-4df1-4dab-9e99-3d2566cc4af1
# To: /Users/priyankasuri/Desktop/Deep-Learning-Projects/Kidney-disease-mlops-project/research/kidney-CT-Scan-data.zip
# 100%|██████████| 57.7M/57.7M [00:15<00:00, 3.79MB/s]
# 'kidney-CT-Scan-data.zip'
